# %% [markdown]
# <a href="https://colab.research.google.com/github/maxidalesio/coderhouse_datascience/blob/main/DatasetsDAlesio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hola google colab")
# Out:
# Hola google colab

# %%
from google.colab import drive
import pandas as pd

# Monta tu drive
drive.mount('/content/drive')

# Ruta al archivo dentro de tu Drive
ruta = "/content/drive/MyDrive/Coderhouse/Data Science I - Comision 77700 - Maximiliano D'Alesio/AppleStore.csv"


df = pd.read_csv(ruta)
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    Unnamed: 0         id                                         track_name  \
# 0           1  281656475                                    PAC-MAN Premium
# 1           2  281796108                          Evernote - stay organized
# 2           3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           5  282935706                                              Bible
#
#    size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0   100788224      USD   3.99             21292                26
# 1   158578688      USD   0.00            161065                26
# 2   100524032      USD   0.00            188583              2822
# 3   128512000      USD   0.00            262241               649
# ...

# %%
from google.colab import drive
import pandas as pd

# Monta tu drive
drive.mount('/content/drive')

# Ruta al archivo dentro de tu Drive
ruta2 = "/content/drive/MyDrive/Coderhouse/Data Science I - Comision 77700 - Maximiliano D'Alesio/global_videogames_sales_2023.csv"


df2 = pd.read_csv(ruta2)
df2.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#                       Name  Year_of_Release         Genre   Publisher  \
# 0  .hack//Infection Part 1           2002.0  Role-Playing       Atari
# 1   .hack//Mutation Part 2           2002.0  Role-Playing       Atari
# 2   .hack//Outbreak Part 3           2002.0  Role-Playing       Atari
# 3              [Prototype]           2009.0        Action  Activision
# 4              [Prototype]           2009.0        Action  Activision
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0      0.49      0.38      0.26         0.13          1.27          75.0
# 1      0.23      0.18      0.20         0.06          0.68          76.0
# 2      0.14      0.11      0.17         0.04          0.46          70.0
# 3      0.84      0.35      0.00         0.12          1.31          78.0
# ...

# %%
from google.colab import drive
import pandas as pd

# Monta tu drive
drive.mount('/content/drive')

# Ruta al archivo dentro de tu Drive
ruta3 = "/content/drive/MyDrive/Coderhouse/Data Science I - Comision 77700 - Maximiliano D'Alesio/multilingual_mobile_app_reviews_2025.csv"

df3 = pd.read_csv(ruta3)
df3.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    review_id  user_id      app_name    app_category  \
# 0          1  1967825     MX Player  Travel & Local
# 1          2  9242600        Tinder      Navigation
# 2          3  7636477       Netflix          Dating
# 3          4   209031         Venmo    Productivity
# 4          5  7190293  Google Drive       Education
#
#                                          review_text review_language  rating  \
# 0  Qui doloribus consequuntur. Perspiciatis tempo...              no     1.3
# 1  Great app but too many ads, consider premium v...              ru     1.6
# 2  The interface could be better but overall good...              es     3.6
# 3  Latest update broke some features, please fix ...              vi     3.8
# 4  Perfect for daily use, highly recommend to eve...              tl     3.2
#
# ...
